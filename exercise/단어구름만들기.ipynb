# %%
import import_ipynb
from aifunctions.wordcloud_functions import create_wc
# Out:
# importing Jupyter notebook from /Users/xzero/python_ex/aimath/exercise/aifunctions/wordcloud_functions.ipynb

# %% [markdown]
# ## 명령사용법
# - "가,나,다"라는 문자가 각각 5번, 5번, 2번의 비중으로 쓰였다면 다음과 같이 명령을 작성하면 됩니다.
# - <code> create_wc(["가","나","다"],[5,5,2])</code>

# %%
# 예시1
create_wc(["가","나","다"],[5,5,2])

# %%
#예시2
create_wc(["abc","가나","ai수학","교육"],[50,50,20,5])
