# %%
import import_ipynb
import wordcloud_functions
# Out:
# importing Jupyter notebook from wordcloud_functions.ipynb

# %%
wordcloud_functions.create_wc(["abc","가나"],[50 ,50])
# Out:
# <module 'matplotlib.pyplot' from '/usr/local/Cellar/jupyterlab/2.2.6/libexec/lib/python3.8/site-packages/matplotlib/pyplot.py'>
